# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##Regression between 311 Reports and Property Crimes

df_main = pd.read_csv("FINAL.csv", 
                      usecols = ['Reports', 'VACperc', 'MEDINC', 'PopOv25wBach', 'PopOv25wHS', 'Property'])



# formula: response ~ predictor + predictor + ... 
est = smf.ols(formula='Property ~ Reports + VACperc + MEDINC + PopOv25wBach + PopOv25wHS', data=df_main).fit()
est.summary()


sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")

# Create scatterplot of dataframe
sns.lmplot('Reports', # Horizontal axis
           'Property', # Vertical axis
           data=df_main, # Data source
           fit_reg=True, # Don't fix a regression line
           scatter_kws={"marker": "D", # Set marker style
                        "s": 100}) # S marker size

# Set title
plt.title('311 Reports and Property Crime Reports')

# Set x-axis label
plt.xlabel('311 Reports')

# Set y-axis label
plt.ylabel('Property Crimes')

plt.show()

# %%
##regression between 311 reports and violent crimes 

df_main = pd.read_csv("FINAL.csv", 
                      usecols = ['Reports', 'VACperc', 'MEDINC', 'PopOv25wBach', 'PopOv25wHS', 'Violent'])



# formula: response ~ predictor + predictor + ... 
est = smf.ols(formula='Violent ~ Reports + VACperc + MEDINC + PopOv25wBach + PopOv25wHS', data=df_main).fit()
est.summary()

sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")

# Create scatterplot of dataframe
sns.lmplot('Reports', # Horizontal axis
           'Violent', # Vertical axis
           data=df_main, # Data source
           fit_reg=True, # Don't fix a regression line
           scatter_kws={"marker": "D", # Set marker style
                        "s": 100}) # S marker size

# Set title
plt.title('311 Reports and Violent Crimes Reported')

# Set x-axis label
plt.xlabel('311 Reports')

# Set y-axis label
plt.ylabel('Violent Crimes')

plt.show()

# %%
##OLS regression violent ~ 311 reports 
import statsmodels.api as sm

df_main = pd.read_csv("FINAL.csv", 
                      usecols = ['Reports', 'Violent'])

X = df_main['Reports']
y = df_main['Violent']

## fit a OLS model with intercept on TV and Radio
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()

est.summary()
# Out:
# /Users/vicky/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Violent   R-squared:                       0.698
# Model:                            OLS   Adj. R-squared:                  0.694
# Method:                 Least Squares   F-statistic:                     173.3
# Date:                Wed, 29 Nov 2017   Prob (F-statistic):           3.47e-21
# Time:                        12:21:04   Log-Likelihood:                -710.62
# No. Observations:                  77   AIC:                             1425.
# Df Residuals:                      75   BIC:                             1430.
# Df Model:                           1
# ...

# %%
##share vacant ~ violent crimes 

import statsmodels.api as sm

df_main = pd.read_csv("FINAL.csv", 
                      usecols = ['VACperc', 'Violent'])

X = df_main['VACperc']
y = df_main['Violent']

## fit a OLS model with intercept on TV and Radio
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()

est.summary()


sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")

# Create scatterplot of dataframe
sns.lmplot('VACperc', # Horizontal axis
           'Violent', # Vertical axis
           data=df_main, # Data source
           fit_reg=True, # Don't fix a regression line
           scatter_kws={"marker": "D", # Set marker style
                        "s": 100}) # S marker size

# Set title
plt.title('Vacant Properties Share and Violent Crime')

# Set x-axis label
plt.xlabel('Share of Vacant Properties')

# Set y-axis label
plt.ylabel('Violent Crimes')

plt.show()

# %%
##share vacant ~ property crimes 
import statsmodels.api as sm

df_main = pd.read_csv("FINAL.csv", 
                      usecols = ['VACperc', 'Property'])

X = df_main['VACperc']
y = df_main['Property']

## fit a OLS model with intercept on TV and Radio
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()

est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Property   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                  0.002038
# Date:                Wed, 29 Nov 2017   Prob (F-statistic):              0.964
# Time:                        12:25:17   Log-Likelihood:                -771.75
# No. Observations:                  77   AIC:                             1548.
# Df Residuals:                      75   BIC:                             1552.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6554.1755    848.957      7.720      0.000    4862.966    8245.385
# ...

# %%
##is 311 reports correlated with demographic factors?

reports_edu = pd.read_csv("FINAL.csv", 
                      usecols = ['Reports', 'PopOv25wHS', 'PopOv25wBach', 'MEDINC'])



# formula: response ~ predictor + predictor + ... 
est = smf.ols(formula= 'Reports ~ PopOv25wHS + PopOv25wBach + MEDINC', data=reports_edu).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Reports   R-squared:                       0.249
# Model:                            OLS   Adj. R-squared:                  0.218
# Method:                 Least Squares   F-statistic:                     8.058
# Date:                Thu, 30 Nov 2017   Prob (F-statistic):           0.000104
# Time:                        22:25:12   Log-Likelihood:                -462.17
# No. Observations:                  77   AIC:                             932.3
# Df Residuals:                      73   BIC:                             941.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
### violent crimes ~ vacant percent 
import statsmodels.api as sm

df_main = pd.read_csv("FINAL.csv", 
                      usecols = ['VACperc', 'Violent'])

X = df_main['VACperc']
y = df_main['Violent']

## fit a OLS model with intercept on TV and Radio
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()

est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Violent   R-squared:                       0.100
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     8.371
# Date:                Fri, 01 Dec 2017   Prob (F-statistic):            0.00499
# Time:                        17:37:24   Log-Likelihood:                -752.64
# No. Observations:                  77   AIC:                             1509.
# Df Residuals:                      75   BIC:                             1514.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3561.9260    662.335      5.378      0.000    2242.487    4881.365
# ...

# %%
##REsiduals analysis of model w controls
df_main = pd.read_csv("FINAL.csv", 
                      usecols = ['Reports', 'VACperc', 'MEDINC', 'PopOv25wBach', 'PopOv25wHS', 'Violent'])



# formula: response ~ predictor + predictor + ... 
est = smf.ols(formula='Violent ~ Reports + VACperc + MEDINC + PopOv25wBach + PopOv25wHS', data=df_main).fit()

df_main = pd.read_csv("FINAL.csv")
sns.regplot(x = df_main["Reports"], y = pd.Series(est.resid, name = "Residual"), scatter_kws = {"alpha" : 0.1});
plt.show()
